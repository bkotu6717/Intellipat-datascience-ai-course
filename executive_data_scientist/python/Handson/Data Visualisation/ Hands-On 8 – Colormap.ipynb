# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('./titanic.csv')
sns.countplot(x='class', legend=False, data=df, palette=['red', 'green', 'blue'])

# sns.countplot(x='class', legend=False, data=df)
# Out:
# /var/folders/vg/mhm89jn94z5g6j6bd9h1flbm0000gn/T/ipykernel_30234/1556670099.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class', legend=False, data=df, palette=['red', 'green', 'blue'])
# <Axes: xlabel='class', ylabel='count'>
