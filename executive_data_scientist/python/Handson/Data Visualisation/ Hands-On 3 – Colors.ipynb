# %%
import matplotlib.pyplot as plt
a = [x*x  for x in range(0,10)]
b = [x*x for x in range(9,-1, -1)]
# plt.plot(a, color='r')
# plt.plot(a, color='b')
# plt.plot(a, color='y')
plt.plot(a, color='red', marker='P')
plt.plot(b, color='green', marker='D')
