# %%
import matplotlib.pyplot as plt
# create a plot with markers that look like the addition symbol

# plt.plot([1,2,3,4,5,6,7,8])
# With marker that looks like addition symbol
plt.plot( [x for x in range(0,10)], marker='P' )
plt.plot( [x for x in range(0,10)], marker='p' )

# Marker that looks like Diamond symbol
plt.plot( [x for x in range(0,10)], marker='D' )
