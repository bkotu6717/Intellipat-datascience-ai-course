# %%
# Problem Statement:
# Consider yourself to be Sam who is a data scientist. He has been approached by
# a telecom company to build some aesthetic graphs to make better sense of the
# customer data.


# print(df.sort_values(by='carb'))

# # Tasks To Be Performed:
# # 1. Generate a bar plot graph for the columns ‘carbs’ and ‘gear’:
# fig, ax = plt.subplots()

# # a. Map the ‘carbs’ onto the x-axis
# # b. Map the ‘gear’ onto the y-axis
# ax.bar(df['carb'], df['gear'])
# # c. Provide the x-axis label as Number of carburetors
# ax.set_xlabel('Number of carburetors')

# # d. Provide the y-axis label as Number of forward gears
# ax.set_ylabel('Number of forward gears')

# # e. Set the title as carbs vs gear
# ax.set_title('carbs vs gear')

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('./customer_churn.csv')
# print(df)

# Tasks To Be Performed:
# 1. Sam has to build a bar-plot for the ‘Contract’ column:
# d. Assign ‘orange’ color to all the bars

# fig, ax = plt.subplots()
# ax.bar(df['Contract'], 1000, color='orange')

# # a. Set the x-axis label to be ‘Contract Type of customer’
# ax.set_xlabel('Contract Type of customer')
# # b. Set the y-axis label to be ‘Count’
# ax.set_ylabel('Count')

# # c. Set the title of the plot to be ‘Distribution of Contract’
# ax.set_title('Distribution of Contract')

# 2. Sam has to build a histogram for the ‘MonthlyCharges’ column:
# plt.hist(df['MonthlyCharges'], color='forestgreen')
# # a. Set the x-axis label to be ‘Monthly Charges Incurred’
# plt.xlabel('Monthly Charges Incurred')
# # b. Set the y-axis label to be ‘Count’
# plt.ylabel('‘Count’')
# # c. Set the title of the plot to be ‘Distribution of Monthly Charges’
# plt.title('Distribution of Monthly Charges')
# d. Assign ‘forestgreen’ color to the bins
# plt.hist(df['MonthlyCharges'], color='forestgreen')

# 3. Sam has to build a scatter-plot between ‘TotalCharges’ and ‘tenure’.
# ‘TotalCharges’ should be on the y-axis and ‘tenure’ should be on the
# x-axis.
# plt.scatter(df['TotalCharges'], df['tenure'], color='indigo')

# a. Set the x-axis label to be ‘Tenure of the customer’
# plt.xlabel('Tenure of the customer')
# # b. Set the y-axis label to be ‘Total chargesIncurred’
# plt.ylabel('Total chargesIncurred')
# # c. Set the title of the plot to be ‘Total Charges vs Tenure’
# plt.title('Total Charges vs Tenure')
# d. Assign ‘indigo’ color to the points
# plt.scatter(df['TotalCharges'], df['tenure'], color='indigo')

# 4. Sam has to build a box-plot between ‘MonthlyCharges’ and
# ‘PaymentMethod’. 
# ‘MonthlyCharges’ should be on the y-axis and
# ‘PaymentMethod’ should be on the x-axis.

# print(df['PaymentMethod'])
# print(df['MonthlyCharges'])
# print(df[df['MonthlyCharges'].isna()])
data = {}
grouped = df.groupby('PaymentMethod')
for name, group in grouped:
    data[name] = group['MonthlyCharges']
print(data)
# for key, value in data.items():
#     print(key, value)
# a. Set the x-axis label to be ‘Payment Method of customer’
# b. Set the y-axis label to be ‘Monthly ChargesIncurred’
# c. Set the title of plot to be ‘Monthly Charges vs. Payment Method’
# d. Assign ‘olive’ color to the box-plots
# Out:
# {'Bank transfer (automatic)': 3        42.30
# 9        56.15
# 13      103.70
# 17      106.70
# 21       19.80
#          ...
# 7026     44.20
# 7028     64.10
# 7035     78.70
# 7037     21.15
# 7042    105.65
# Name: MonthlyCharges, Length: 1544, dtype: float64, 'Credit card (automatic)': 6        89.10
# 11       18.95
# 12      100.35
# 15      113.25
# 18       55.20
#          ...
# 7024     84.80
# 7031     60.00
# 7033     69.50
# 7034    102.95
# 7039    103.20
# Name: MonthlyCharges, Length: 1522, dtype: float64, 'Electronic check': 0        29.85
# 4        70.70
# 5        99.65
# 8       104.80
# 14      105.50
#          ...
# 7023    103.50
# 7029     44.40
# 7032     75.75
# 7036     60.65
# 7040     29.60
# Name: MonthlyCharges, Length: 2365, dtype: float64, 'Mailed check': 1       56.95
# 2       53.85
# 7       29.75
# 10      49.95
# 16      20.65
#         ...
# 7019    20.15
# 7027    73.35
# 7030    20.05
# 7038    84.80
# 7041    74.40
# Name: MonthlyCharges, Length: 1612, dtype: float64}
# Bank transfer (automatic) 3        42.30
# 9        56.15
# 13      103.70
# 17      106.70
# 21       19.80
#          ...
# 7026     44.20
# 7028     64.10
# 7035     78.70
# 7037     21.15
# 7042    105.65
# Name: MonthlyCharges, Length: 1544, dtype: float64
# Credit card (automatic) 6        89.10
# 11       18.95
# 12      100.35
# 15      113.25
# 18       55.20
#          ...
# 7024     84.80
# 7031     60.00
# 7033     69.50
# 7034    102.95
# 7039    103.20
# Name: MonthlyCharges, Length: 1522, dtype: float64
# Electronic check 0        29.85
# 4        70.70
# 5        99.65
# 8       104.80
# 14      105.50
#          ...
# 7023    103.50
# 7029     44.40
# 7032     75.75
# 7036     60.65
# 7040     29.60
# Name: MonthlyCharges, Length: 2365, dtype: float64
# Mailed check 1       56.95
# 2       53.85
# 7       29.75
# 10      49.95
# 16      20.65
#         ...
# 7019    20.15
# 7027    73.35
# 7030    20.05
# 7038    84.80
# 7041    74.40
# Name: MonthlyCharges, Length: 1612, dtype: float64
