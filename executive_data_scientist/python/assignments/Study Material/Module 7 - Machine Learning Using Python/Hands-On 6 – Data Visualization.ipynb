# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./Files/time_series.csv")

# %%
data.head()
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
# 3  2-Apr-07  12.930043  41.560001  54.588032  235.925919  81.934280
# 4  1-May-07  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %% [markdown]
# ## Step 5: Plot a line graph and take a look at Google’s historical data about its stock price

# %%
plt.plot(data['Date'], data['GOOG'])
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Step 6: Read data from national parks and take a look at first 5 rows

# %%
data = pd.read_csv("./Files/national_parks.csv")

# %%
data.iloc[0:5,:]
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %% [markdown]
# ## Step 7: Plot a histogram based on the ‘GrandCanyon’ column

# %%
plt.hist(data['GrandCanyon'])
plt.show()

# %% [markdown]
# ## Step 8: Read data from ‘types_movies.csv’ and take a look at first 5 rows

# %%
data = pd.read_csv("./Files/types_movies.csv")

# %%
data.head()
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %% [markdown]
# # Step 9: Plot a pie chart based on percentage of movies and set labels to be sector column

# %%
plt.pie(data['Percentage'], labels=data['Sector'])
plt.show()

# %% [markdown]
# ## Step 10: Create and visualize a correlation matrix on time_series data using heatmaps

# %%
data = pd.read_csv("./Files/time_series.csv")

# %%
data.head()
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
# 3  2-Apr-07  12.930043  41.560001  54.588032  235.925919  81.934280
# 4  1-May-07  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
matrix = data.iloc[:, 1:].corr()

# %%
matrix
# Out:
#           AAPL      ADBE       CVX      GOOG       IBM      MDLZ      MSFT  \
# AAPL  1.000000  0.807632  0.802450  0.873487  0.736053  0.933486  0.863291
# ADBE  0.807632  1.000000  0.603587  0.959471  0.372347  0.926608  0.974946
# CVX   0.802450  0.603587  1.000000  0.724059  0.904300  0.773167  0.668932
# GOOG  0.873487  0.959471  0.724059  1.000000  0.540521  0.967450  0.973541
# IBM   0.736053  0.372347  0.904300  0.540521  1.000000  0.624925  0.474023
# MDLZ  0.933486  0.926608  0.773167  0.967450  0.624925  1.000000  0.944829
# MSFT  0.863291  0.974946  0.668932  0.973541  0.474023  0.944829  1.000000
# NFLX  0.851237  0.924177  0.619611  0.939631  0.462910  0.934208  0.929809
# ORCL  0.936432  0.782531  0.870343  0.863979  0.779647  0.906243  0.822729
# SBUX  0.929173  0.915468  0.734699  0.958740  0.606088  0.985732  0.938071
#
#           NFLX      ORCL      SBUX
# AAPL  0.851237  0.936432  0.929173
# ADBE  0.924177  0.782531  0.915468
# CVX   0.619611  0.870343  0.734699
# GOOG  0.939631  0.863979  0.958740
# IBM   0.462910  0.779647  0.606088
# MDLZ  0.934208  0.906243  0.985732
# MSFT  0.929809  0.822729  0.938071
# NFLX  1.000000  0.831860  0.936006
# ORCL  0.831860  1.000000  0.888980
# SBUX  0.936006  0.888980  1.000000

# %%
sns.heatmap(matrix)
sns.annot = True
