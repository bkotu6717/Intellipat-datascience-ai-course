# %% [markdown]
# ![Screenshot 2024-01-29 at 5.26.37 AM.png](attachment:a48d61a8-4ef7-4112-a777-a07f62a32800.png)

# %% [markdown]
# ![Screenshot 2024-01-29 at 5.36.18 AM.png](attachment:8b999e2a-a42f-4e5c-90a4-5bd38a1a57f4.png)

# %% [markdown]
# ![Screenshot 2024-01-29 at 5.39.23 AM.png](attachment:02236d47-e543-42ec-a606-ef238362d81c.png)

# %%
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df.head()
filter = (df['YearsExperience'] > 5) & (df['Salary'] > 60000)
df[filter].count()
# Ans: 14
# Out:
# YearsExperience    14
# Salary             14
# dtype: int64

# %% [markdown]
# ![Screenshot 2024-01-29 at 5.58.32 AM.png](attachment:a139ce4b-2d06-4bb8-a373-7c1582339816.png)

# %%
df.head()
filter = (df['Salary'] > 50000) & (df['Salary'] < 80000)
df[filter].count()
# Ans: 12
# Out:
# YearsExperience    12
# Salary             12
# dtype: int64

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.00.29 AM.png](attachment:5c0e9279-bf7a-4fc9-a6a5-0d6c31e05a0c.png)

# %%
# Ans : a

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.02.22 AM.png](attachment:99771ed2-0238-42fa-980a-a6d79421adbb.png)

# %%
# Ans: b

# %% [markdown]
# # 5. What all inferences can be drawn from the table shown below:
# ![Screenshot 2024-01-29 at 6.04.20 AM.png](attachment:d819f45d-5b11-4115-83ad-67580c42d4ac.png)

# %%
df.describe()
# Ans: d
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.10.19 AM.png](attachment:9d3f0b04-819c-4631-814d-8b26749d4a52.png)

# %%
# Ans :d

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.12.16 AM.png](attachment:83c14612-cd28-461a-9eea-558a4427794b.png)

# %%
# Ans: d

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.16.07 AM.png](attachment:78d41db8-9bb0-465a-9e6a-ac0febea9f3b.png)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
x, y = df.iloc[:, 0:1], df.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.40, random_state=42)

# %%
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = clf.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9532338376280692

# %%
# Ans: b

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.49.21 AM.png](attachment:315f92d0-5d7b-4e06-b908-fa89b88d7727.png)

# %%
# Ans: c

# %% [markdown]
# ## The exercise after this contains questions that are based on the housing dataset.

# %%
df = pd.read_csv('./housing.csv')
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ![Screenshot 2024-01-30 at 5.48.19 AM.png](attachment:ecca35a6-782b-4bd0-b892-ace7b6bd854c.png)

# %%
waterfront_houses = (df['waterfront'] == 1)
df[waterfront_houses].count()
# Ans: c
# Out:
# id               163
# date             163
# price            163
# bedrooms         163
# bathrooms        163
# sqft_living      163
# sqft_lot         163
# floors           163
# waterfront       163
# view             163
# condition        163
# grade            163
# sqft_above       163
# sqft_basement    163
# yr_built         163
# yr_renovated     163
# zipcode          163
# lat              163
# long             163
# sqft_living15    163
# sqft_lot15       163
# dtype: int64

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.02.12 AM.png](attachment:9c82b720-5eb2-476b-b877-89fd54bae2db.png)

# %%
two_floor_houses = (df['floors'] == 2.0)
df[two_floor_houses].count()
# Ans: b
# Out:
# id               8241
# date             8241
# price            8241
# bedrooms         8241
# bathrooms        8241
# sqft_living      8241
# sqft_lot         8241
# floors           8241
# waterfront       8241
# view             8241
# condition        8241
# grade            8241
# sqft_above       8241
# sqft_basement    8241
# yr_built         8241
# yr_renovated     8241
# zipcode          8241
# lat              8241
# long             8241
# sqft_living15    8241
# sqft_lot15       8241
# dtype: int64

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.03.46 AM.png](attachment:236893a3-98d9-4fc3-acd9-d896200e0938.png)

# %%
houses_filter = (df.yr_built < 1960) & (df.waterfront == 1)
df[houses_filter].count()
# Ans: a
# Out:
# id               80
# date             80
# price            80
# bedrooms         80
# bathrooms        80
# sqft_living      80
# sqft_lot         80
# floors           80
# waterfront       80
# view             80
# condition        80
# grade            80
# sqft_above       80
# sqft_basement    80
# yr_built         80
# yr_renovated     80
# zipcode          80
# lat              80
# long             80
# sqft_living15    80
# sqft_lot15       80
# dtype: int64

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.06.56 AM.png](attachment:bc6e4406-2bac-44de-be89-9ca5c314dc22.png)

# %%
houses_filter = (df.bathrooms > 4)
df[houses_filter].price.max()
# Ans: a
# Out:
# 7700000

# %%
# 14. The image shown below shows the boxplot of the price column from the housing
# dataset. What inferences can you make from the plot?
# Ans: c

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.10.59 AM.png](attachment:452f746c-5131-4d21-bf17-b5d2717590f5.png)

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.12.38 AM.png](attachment:e945c95d-6093-4c00-87b0-40ae91065d7c.png)

# %%
# Ans: a

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.14.59 AM.png](attachment:d5b2af02-bb65-49bd-9131-8077965f09fa.png)

# %%
# Ans: a

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.17.03 AM.png](attachment:5e4a9692-effb-46d5-9607-e1fa88723a79.png)

# %%
# Ans: a

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.18.31 AM.png](attachment:b013383a-4045-4dcd-86d0-ebe8cf50221e.png)

# %%
# Ans: c

# %% [markdown]
# ![Screenshot 2024-01-30 at 6.22.34 AM.png](attachment:a55d9d99-ce37-4e64-8e28-43bfe2b1f59d.png)

# %%
# Ans: c
