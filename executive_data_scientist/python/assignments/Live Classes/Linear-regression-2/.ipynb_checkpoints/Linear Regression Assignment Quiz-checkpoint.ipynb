# %% [markdown]
# ![Screenshot 2024-01-29 at 5.26.37 AM.png](attachment:a48d61a8-4ef7-4112-a777-a07f62a32800.png)

# %% [markdown]
# ![Screenshot 2024-01-29 at 5.36.18 AM.png](attachment:8b999e2a-a42f-4e5c-90a4-5bd38a1a57f4.png)

# %% [markdown]
# ![Screenshot 2024-01-29 at 5.39.23 AM.png](attachment:02236d47-e543-42ec-a606-ef238362d81c.png)

# %%
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df.head()
filter = (df['YearsExperience'] > 5) & (df['Salary'] > 60000)
df[filter].count()
# Ans: 14
# Out:
# YearsExperience    14
# Salary             14
# dtype: int64

# %% [markdown]
# ![Screenshot 2024-01-29 at 5.58.32 AM.png](attachment:a139ce4b-2d06-4bb8-a373-7c1582339816.png)

# %%
filter = (df['Salary'] > 50000) & (df['Salary'] > 80000)
df[filter].count()
# Ans: 13
# Out:
# YearsExperience    13
# Salary             13
# dtype: int64

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.00.29 AM.png](attachment:5c0e9279-bf7a-4fc9-a6a5-0d6c31e05a0c.png)

# %%
# Ans : a

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.02.22 AM.png](attachment:99771ed2-0238-42fa-980a-a6d79421adbb.png)

# %%
# Ans: b

# %% [markdown]
# # 5. What all inferences can be drawn from the table shown below:
# ![Screenshot 2024-01-29 at 6.04.20 AM.png](attachment:d819f45d-5b11-4115-83ad-67580c42d4ac.png)

# %%
df.describe()
# Ans: d
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.10.19 AM.png](attachment:9d3f0b04-819c-4631-814d-8b26749d4a52.png)

# %%
# Ans :d

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.12.16 AM.png](attachment:83c14612-cd28-461a-9eea-558a4427794b.png)

# %%
# Ans: d

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.16.07 AM.png](attachment:78d41db8-9bb0-465a-9e6a-ac0febea9f3b.png)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
x, y = df.iloc[:, 0:1], df.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.40, random_state=42)

# %%
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = clf.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9532338376280692

# %%
# Ans: b

# %% [markdown]
# ![Screenshot 2024-01-29 at 6.49.21 AM.png](attachment:315f92d0-5d7b-4e06-b908-fa89b88d7727.png)

# %%
# Ans: c
