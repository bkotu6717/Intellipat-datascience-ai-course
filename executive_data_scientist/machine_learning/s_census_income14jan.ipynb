# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/census-income.csv', skipinitialspace = True, na_values = '?') # na_values will change all ? into NAN values
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# 1             0             0              13  United-States         <=50K
# 2             0             0              40  United-States         <=50K
# 3             0             0              40  United-States         <=50K
# 4             0             0              40           Cuba         <=50K

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace('-','_')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'annual_income'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  31978 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data["workclass"].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# annual_income        0
# dtype: int64

# %%
data["workclass"].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
#Removing null values
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# annual_income     0
# dtype: int64

# %%
#Data Manipulation
#Q Extractracting the “education” column and store it in “census_ed” .
census_ed=data[['education']]
census_ed.head()
# Out:
#    education
# 0  Bachelors
# 1  Bachelors
# 2    HS-grad
# 3       11th
# 4  Bachelors

# %%
#) Q .Extracting all the columns from “age” to “relationship” and store it in “census_seq”.
census_seq=data.iloc[:,0:8]
census_seq.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship
# 0       Never-married       Adm-clerical  Not-in-family
# 1  Married-civ-spouse    Exec-managerial        Husband
# 2            Divorced  Handlers-cleaners  Not-in-family
# 3  Married-civ-spouse  Handlers-cleaners        Husband
# 4  Married-civ-spouse     Prof-specialty           Wife

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country annual_income
# 0          2174             0              40  United-States         <=50K
# 1             0             0              13  United-States         <=50K
# 2             0             0              40  United-States         <=50K
# 3             0             0              40  United-States         <=50K
# 4             0             0              40           Cuba         <=50K

# %%
census_seq = data.loc[:,'age':'relationship']
census_seq
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# 2                Divorced  Handlers-cleaners  Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners        Husband
# 4      Married-civ-spouse     Prof-specialty           Wife
# ...                   ...                ...            ...
# 32556  Married-civ-spouse       Tech-support           Wife
# 32557  Married-civ-spouse  Machine-op-inspct        Husband
# 32558             Widowed       Adm-clerical      Unmarried
# 32559       Never-married       Adm-clerical      Own-child
# 32560  Married-civ-spouse    Exec-managerial           Wife
#
# [30162 rows x 8 columns]

# %%
#Q Extract the column number “0”, “5”, “6” and store it in “census_col”.
census_col=data.iloc[:,[0,5,6]]
census_col.head()
# Out:
#    age      marital_status         occupation
# 0   39       Never-married       Adm-clerical
# 1   50  Married-civ-spouse    Exec-managerial
# 2   38            Divorced  Handlers-cleaners
# 3   53  Married-civ-spouse  Handlers-cleaners
# 4   28  Married-civ-spouse     Prof-specialty

# %%
#)Q.  Extracting all the male employees who work in state-gov and store it in “male_gov”.
male_gov=data[(data['workclass']=='State-gov') & (data['sex']=='Male')]
male_gov.head()
# Out:
#      age  workclass  fnlwgt     education  education_num      marital_status  \
# 0     39  State-gov   77516     Bachelors             13       Never-married
# 11    30  State-gov  141297     Bachelors             13  Married-civ-spouse
# 34    22  State-gov  311512  Some-college             10  Married-civ-spouse
# 48    41  State-gov  101603     Assoc-voc             11  Married-civ-spouse
# 123   29  State-gov  267989     Bachelors             13  Married-civ-spouse
#
#          occupation   relationship                race   sex  capital_gain  \
# 0      Adm-clerical  Not-in-family               White  Male          2174
# 11   Prof-specialty        Husband  Asian-Pac-Islander  Male             0
# 34    Other-service        Husband               Black  Male             0
# 48     Craft-repair        Husband               White  Male             0
# 123  Prof-specialty        Husband               White  Male             0
#
#      capital_loss  hours_per_week native_country annual_income
# 0               0              40  United-States         <=50K
# 11              0              40          India          >50K
# 34              0              15  United-States         <=50K
# 48              0              40  United-States         <=50K
# 123             0              50  United-States          >50K

# %%
#Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States and store the result in “census_us”.
census = data[(data['age']==39)]
#census
census_us=census[(census['education']=='Bachelors') | (census['native_country']==' United-States')]
census_us.head()
# Out:
#       age     workclass  fnlwgt  education  education_num      marital_status  \
# 0      39     State-gov   77516  Bachelors             13       Never-married
# 848    39       Private  138192  Bachelors             13  Married-civ-spouse
# 915    39       Private  202027  Bachelors             13  Married-civ-spouse
# 999    39  Self-emp-inc  329980  Bachelors             13  Married-civ-spouse
# 1336   39       Private  174938  Bachelors             13       Never-married
#
#            occupation   relationship   race   sex  capital_gain  capital_loss  \
# 0        Adm-clerical  Not-in-family  White  Male          2174             0
# 848      Craft-repair        Husband  White  Male             0             0
# 915   Exec-managerial        Husband  White  Male         15024             0
# 999   Exec-managerial        Husband  White  Male         15024             0
# 1336   Prof-specialty  Not-in-family  White  Male             0             0
#
#       hours_per_week native_country annual_income
# 0                 40  United-States         <=50K
# 848               40  United-States         <=50K
# 915               45  United-States          >50K
# 999               50  United-States          >50K
# 1336              40  United-States         <=50K

# %%
census
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors             13
# 28      39           Private  367260       HS-grad              9
# 129     39           Private  365739  Some-college             10
# 166     39       Federal-gov  235485    Assoc-acdm             12
# 320     39  Self-emp-not-inc  174308       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32260   39       Federal-gov  232036  Some-college             10
# 32378   39           Private  214896       HS-grad              9
# 32428   39       Federal-gov  110622     Bachelors             13
# 32468   39  Self-emp-not-inc  193689       HS-grad              9
# 32545   39         Local-gov  111499    Assoc-acdm             12
#
#            marital_status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# 28               Divorced  Exec-managerial  Not-in-family               White
# 129              Divorced     Craft-repair  Not-in-family               White
# 166         Never-married  Exec-managerial  Not-in-family               White
# 320    Married-civ-spouse  Exec-managerial        Husband               White
# ...                   ...              ...            ...                 ...
# 32260  Married-civ-spouse     Adm-clerical        Husband               White
# 32378           Separated    Other-service  Not-in-family               White
# 32428  Married-civ-spouse     Adm-clerical           Wife  Asian-Pac-Islander
# 32468       Never-married  Exec-managerial  Not-in-family               White
# 32545  Married-civ-spouse     Adm-clerical           Wife               White
#
#           sex  capital_gain  capital_loss  hours_per_week native_country  \
# 0        Male          2174             0              40  United-States
# 28       Male             0             0              80  United-States
# 129      Male             0             0              40  United-States
# 166      Male             0             0              42  United-States
# 320      Male             0             0              40  United-States
# ...       ...           ...           ...             ...            ...
# 32260    Male             0             0              40  United-States
# 32378  Female             0             0              40    El-Salvador
# 32428  Female             0             0              40    Philippines
# 32468    Male             0             0              65  United-States
# 32545  Female             0             0              20  United-States
#
#       annual_income
# 0             <=50K
# 28            <=50K
# 129           <=50K
# 166           <=50K
# 320           <=50K
# ...             ...
# 32260          >50K
# 32378         <=50K
# 32428         <=50K
# 32468         <=50K
# 32545          >50K
#
# [786 rows x 15 columns]

# %%
# Q sample() helps us to get random rows
census_200= data.sample(200)
census_200
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 22134   29           Private  114158  Some-college             10
# 8468    43           Private  115178     Assoc-voc             11
# 2247    64         Local-gov   78866       HS-grad              9
# 10906   32      Self-emp-inc   78530  Some-college             10
# 30018   49           Private   31807  Some-college             10
# ...    ...               ...     ...           ...            ...
# 26967   49      Self-emp-inc  101722   Prof-school             15
# 25854   42  Self-emp-not-inc  102069       7th-8th              4
# 28766   36           Private  207789       HS-grad              9
# 18517   20           Private  173851  Some-college             10
# 11414   41           Private  193995       HS-grad              9
#
#            marital_status       occupation   relationship   race     sex  \
# 22134       Never-married   Prof-specialty  Not-in-family  White  Female
# 8468   Married-civ-spouse     Adm-clerical           Wife  White  Female
# 2247             Divorced     Adm-clerical  Not-in-family  White  Female
# 10906  Married-civ-spouse  Exec-managerial        Husband  White    Male
# 30018       Never-married  Exec-managerial      Unmarried  White  Female
# ...                   ...              ...            ...    ...     ...
# 26967  Married-civ-spouse   Prof-specialty        Husband  White    Male
# 25854  Married-civ-spouse            Sales        Husband  White    Male
# 28766            Divorced  Exec-managerial  Not-in-family  White    Male
# 18517       Never-married  Farming-fishing      Own-child  White    Male
# 11414       Never-married     Craft-repair  Not-in-family  White    Male
#
#        capital_gain  capital_loss  hours_per_week native_country annual_income
# 22134             0             0              40  United-States         <=50K
# 8468              0             0              40  United-States          >50K
# 2247              0             0              40  United-States         <=50K
# 10906         15024             0              50  United-States          >50K
# 30018             0             0              40  United-States         <=50K
# ...             ...           ...             ...            ...           ...
# 26967             0             0              60  United-States          >50K
# 25854             0             0              30  United-States         <=50K
# 28766             0             0              52  United-States         <=50K
# 18517             0             0              40  United-States         <=50K
# 11414             0             0              44  United-States         <=50K
#
# [200 rows x 15 columns]

# %%
#Extracting males and females seperately whose income is more than 50k
male_50k=data[(data['sex']=='Male') & (data['annual_income']=='>50K')]
female_50K=data[(data['sex']=='Female') & (data['annual_income']=='>50K')]

# %%
female_50K
# Out:
#        age         workclass  fnlwgt    education  education_num  \
# 8       31           Private   45781      Masters             14
# 19      43  Self-emp-not-inc  292175      Masters             14
# 52      47           Private   51835  Prof-school             15
# 67      53           Private  169846      HS-grad              9
# 84      44           Private  343591      HS-grad              9
# ...    ...               ...     ...          ...            ...
# 32513   46           Private   42972      Masters             14
# 32536   34           Private  160216    Bachelors             13
# 32538   38           Private  139180    Bachelors             13
# 32545   39         Local-gov  111499   Assoc-acdm             12
# 32560   52      Self-emp-inc  287927      HS-grad              9
#
#            marital_status       occupation   relationship   race     sex  \
# 8           Never-married   Prof-specialty  Not-in-family  White  Female
# 19               Divorced  Exec-managerial      Unmarried  White  Female
# 52     Married-civ-spouse   Prof-specialty           Wife  White  Female
# 67     Married-civ-spouse     Adm-clerical           Wife  White  Female
# 84               Divorced     Craft-repair  Not-in-family  White  Female
# ...                   ...              ...            ...    ...     ...
# 32513  Married-civ-spouse   Prof-specialty           Wife  White  Female
# 32536       Never-married  Exec-managerial  Not-in-family  White  Female
# 32538            Divorced   Prof-specialty      Unmarried  Black  Female
# 32545  Married-civ-spouse     Adm-clerical           Wife  White  Female
# 32560  Married-civ-spouse  Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country annual_income
# 8             14084             0              50  United-States          >50K
# 19                0             0              45  United-States          >50K
# 52                0          1902              60       Honduras          >50K
# 67                0             0              40  United-States          >50K
# 84            14344             0              40  United-States          >50K
# ...             ...           ...             ...            ...           ...
# 32513             0             0              22  United-States          >50K
# 32536             0             0              55  United-States          >50K
# 32538         15020             0              45  United-States          >50K
# 32545             0             0              20  United-States          >50K
# 32560         15024             0              40  United-States          >50K
#
# [1112 rows x 15 columns]

# %%
male_50k
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 20      40           Private  193524     Doctorate             16
# ...    ...               ...     ...           ...            ...
# 32519   46           Private  364548  Some-college             10
# 32532   34           Private  204461     Doctorate             16
# 32533   54           Private  337992     Bachelors             13
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
#
#            marital_status         occupation relationship                race  \
# 7      Married-civ-spouse    Exec-managerial      Husband               White
# 9      Married-civ-spouse    Exec-managerial      Husband               White
# 10     Married-civ-spouse    Exec-managerial      Husband               Black
# 11     Married-civ-spouse     Prof-specialty      Husband  Asian-Pac-Islander
# 20     Married-civ-spouse     Prof-specialty      Husband               White
# ...                   ...                ...          ...                 ...
# 32519  Married-civ-spouse    Exec-managerial      Husband               White
# 32532  Married-civ-spouse     Prof-specialty      Husband               White
# 32533  Married-civ-spouse    Exec-managerial      Husband  Asian-Pac-Islander
# 32554  Married-civ-spouse    Exec-managerial      Husband               White
# 32557  Married-civ-spouse  Machine-op-inspct      Husband               White
#
#         sex  capital_gain  capital_loss  hours_per_week native_country  \
# 7      Male             0             0              45  United-States
# 9      Male          5178             0              40  United-States
# 10     Male             0             0              80  United-States
# 11     Male             0             0              40          India
# 20     Male             0             0              60  United-States
# ...     ...           ...           ...             ...            ...
# 32519  Male             0             0              48  United-States
# 32532  Male             0             0              60  United-States
# 32533  Male             0             0              50          Japan
# 32554  Male             0             0              40  United-States
# 32557  Male             0             0              40  United-States
#
#       annual_income
# 7              >50K
# 9              >50K
# 10             >50K
# 11             >50K
# 20             >50K
# ...             ...
# 32519          >50K
# 32532          >50K
# 32533          >50K
# 32554          >50K
# 32557          >50K
#
# [6396 rows x 15 columns]

# %%
#Calculatig the percentage of high school graduates earning more than 50,000 annually

total = len(data['education'])
hs_m50k=len(data[(data['education']=='HS-grad') &(data['annual_income']=='>50K')])

percentage_hs_m50k=(hs_m50k/total)*100

percentage_hs_m50k
# Out:
# 5.361050328227571

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country annual_income
# 0          2174             0              40  United-States         <=50K
# 1             0             0              13  United-States         <=50K
# 2             0             0              40  United-States         <=50K
# 3             0             0              40  United-States         <=50K
# 4             0             0              40           Cuba         <=50K

# %% [markdown]
# # Linear Regression Model

# %%
# Target column : Hours per week
# Independent column : Education_num

# %%
# Model building part

# seperate independent and dependent columns
# train test split
# build our model --- checking for classification or regression models ----> fit_transform
# make predictions
# evaluating our model
# if a classification model :  accuracy score, confusion matrix, classification report
# if a regression model : r2 score, adjusted r2 score, mse, rmse, mae

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

# %%
lr=LinearRegression()   #making an object of linear regression class

# %%
#As per the question independent variable is “education.num”.
x=data[['education_num']]
#dependent variable is “hours.per.week”
y=data['hours_per_week']

# %%
x
# Out:
#        education_num
# 0                 13
# 1                 13
# 2                  9
# 3                  7
# 4                 13
# ...              ...
# 32556             12
# 32557              9
# 32558              9
# 32559              9
# 32560              9
#
# [30162 rows x 1 columns]

# %%
y
# Out:
# 0        40
# 1        13
# 2        40
# 3        40
# 4        40
#          ..
# 32556    38
# 32557    40
# 32558    40
# 32559    20
# 32560    40
# Name: hours_per_week, Length: 30162, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
y_pred   #These are the predicted values
# Out:
# array([40.1516711 , 38.07360531, 42.92242549, ..., 40.1516711 ,
#        38.7662939 , 40.1516711 ])

# %%
y_test #these are actual values
# Out:
# 12488    65
# 5130     50
# 8616     15
# 15453    40
# 13555    50
#          ..
# 23848    32
# 14755    20
# 11213    20
# 15473    40
# 37       25
# Name: hours_per_week, Length: 9049, dtype: int64

# %%
print('mean_squared_error :',mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error : 134.69130460518096

# %%
print('root_mean_squared_error :',mean_squared_error(y_test,y_pred, squared = False ))
# Out:
# root_mean_squared_error : 11.605658301241725

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 7.362283271359862

# %%
r2_score(y_test,y_pred)
# Out:
# 0.02781973266918525

# %%
import seaborn as sns
sns.regplot(x=y_test,y=y_pred,color='red')
# Out:
# <Axes: xlabel='hours_per_week'>

# %%
3# The columns for which we are finding linear regression , they are not in linear relationship hence very bad accuracy we got

# %% [markdown]
# # Logistic Regression

# %%
#AS per question occupation is indpendent and annual_income is target

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lo=LogisticRegression()

# %%
x=data[['occupation']]
# giving particular labels to the elements in my columns
L=LabelEncoder()
x=L.fit_transform(x)
x
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0, 3, 5, ..., 0, 0, 3])

# %%
x=pd.DataFrame(x)
x
# Out:
#         0
# 0       0
# 1       3
# 2       5
# 3       5
# 4       9
# ...    ..
# 30157  12
# 30158   6
# 30159   0
# 30160   0
# 30161   3
#
# [30162 rows x 1 columns]

# %%
y=data['annual_income'].replace('<=50K',0).replace('>50K',1)
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: annual_income, Length: 30162, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.35,random_state=1)
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[7932 2625]
#  [   0    0]]
# accuracy_score : 0.7513498152884343

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country annual_income
# 0          2174             0              40  United-States         <=50K
# 1             0             0              13  United-States         <=50K
# 2             0             0              40  United-States         <=50K
# 3             0             0              40  United-States         <=50K
# 4             0             0              40           Cuba         <=50K

# %%
d=data[['age','workclass','education']]    #We are taking this because income is most related to these columns
d.head()
# Out:
#    age         workclass  education
# 0   39         State-gov  Bachelors
# 1   50  Self-emp-not-inc  Bachelors
# 2   38           Private    HS-grad
# 3   53           Private       11th
# 4   28           Private  Bachelors

# %%
x=d.apply(L.fit_transform)
x.head()
# Out:
#    age  workclass  education
# 0   22          5          9
# 1   33          4          9
# 2   21          2         11
# 3   36          2          1
# 4   11          2          9

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[4349 1499]
#  [ 134   51]]
# accuracy_score : 0.7293220619923753

# %% [markdown]
# TP FP
#
# FN TN
#
# PRECISION  = TP/TP+FP
#
# RECALL     = TP/ TP+ FN
#
# ```
# # This is formatted as code
# ```

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84      4483
#            1       0.28      0.03      0.06      1550
#
#     accuracy                           0.73      6033
#    macro avg       0.51      0.50      0.45      6033
# weighted avg       0.62      0.73      0.64      6033

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
data=data.apply(L.fit_transform)
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   22          5    2491          9             12               4
# 1   33          4    2727          9             12               2
# 2   21          2   13188         11              8               0
# 3   36          2   14354          1              6               2
# 4   11          2   18120          9             12               2
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           0             1     4    1            24             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours_per_week  native_country  annual_income
# 0              39              38              0
# 1              12              38              0
# 2              39              38              0
# 3              39              38              0
# 4              39               4              0

# %%
#independent
x=data.iloc[:,:-1]
#dependent
y=data.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[5862  909]
#  [ 907 1371]]
# accuracy_score : 0.7993148414189413

# %%
from sklearn import tree
tree.plot_tree(dt, fontsize = 7)
# Out:
# [Text(0.6994807784674718, 0.9878048780487805, 'x[7] <= 0.5\ngini = 0.373\nsamples = 21113\nvalue = [15885, 5228]'),
#  Text(0.45951496387961627, 0.9634146341463414, 'x[4] <= 11.5\ngini = 0.495\nsamples = 8756\nvalue = [4806, 3950]'),
#  Text(0.2937674869188782, 0.9390243902439024, 'x[10] <= 77.0\ngini = 0.446\nsamples = 6140\nvalue = [4075, 2065]'),
#  Text(0.1271640481666603, 0.9146341463414634, 'x[4] <= 7.5\ngini = 0.42\nsamples = 5815\nvalue = [4068, 1747]'),
#  Text(0.028943053530229277, 0.8902439024390244, 'x[11] <= 40.0\ngini = 0.187\nsamples = 938\nvalue = [840, 98]'),
#  Text(0.02008153792437717, 0.8658536585365854, 'x[4] <= 4.5\ngini = 0.177\nsamples = 920\nvalue = [830, 90]'),
#  Text(0.01173091800338201, 0.8414634146341463, 'x[12] <= 48.5\ngini = 0.106\nsamples = 463\nvalue = [437, 26]'),
#  Text(0.007250097557969973, 0.8170731707317073, 'x[1] <= 0.5\ngini = 0.069\nsamples = 389\nvalue = [375, 14]'),
#  Text(0.00550432335845879, 0.7926829268292683, 'x[8] <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.00506616826524814, 0.7682926829268293, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.005942478451669439, 0.7682926829268293, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.008995871757481157, 0.7926829268292683, 'x[2] <= 20036.0\ngini = 0.065\nsamples = 387\nvalue = [374, 13]'),
#  Text(0.006818788638090739, 0.7682926829268293, 'x[6] <= 10.5\ngini = 0.061\nsamples = 384\nvalue = [372, 12]'),
#  Text(0.0037790876789418554, 0.7439024390243902, 'x[2] <= 702.0\ngini = 0.042\nsamples = 326\nvalue = [319, 7]'),
#  Text(0.0024098530126585747, 0.7195121951219512, 'x[2] <= 641.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.0019716979194479246, 0.6951219512195121, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.0028480081058692244, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005148322345225136, 0.7195121951219512, 'x[2] <= 19687.0\ngini = 0.037\nsamples = 319\nvalue = [313, 6]'),
#  Text(0.003724318292290524, 0.6951219512195121, 'x[6] <= 3.5\ngini = 0.032\nsamples = 311\nvalue = [306, 5]'),
#  Text(0.0021907754660532497, 0.6707317073170732, 'x[6] <= 2.5\ngini = 0.065\nsamples = 119\nvalue = [115, 4]'),
#  Text(0.0013144652796319497, 0.6463414634146342, 'x[8] <= 2.5\ngini = 0.018\nsamples = 110\nvalue = [109, 1]'),
#  Text(0.0008763101864212998, 0.6219512195121951, 'x[1] <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.0004381550932106499, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0013144652796319497, 0.5975609756097561, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.0017526203728425995, 0.6219512195121951, 'gini = 0.0\nsamples = 105\nvalue = [105, 0]'),
#  Text(0.0030670856524745494, 0.6463414634146342, 'x[1] <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.0026289305592638993, 0.6219512195121951, 'x[1] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.0021907754660532497, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0030670856524745494, 0.5975609756097561, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.003505240745685199, 0.6219512195121951, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.005257861118527799, 0.6707317073170732, 'x[3] <= 3.5\ngini = 0.01\nsamples = 192\nvalue = [191, 1]'),
#  Text(0.004819706025317149, 0.6463414634146342, 'x[0] <= 24.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.004381550932106499, 0.6219512195121951, 'x[0] <= 22.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.003943395838895849, 0.5975609756097561, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.004819706025317149, 0.5975609756097561, 'x[2] <= 8603.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.004381550932106499, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.005257861118527799, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005257861118527799, 0.6219512195121951, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.005696016211738449, 0.6463414634146342, 'gini = 0.0\nsamples = 169\nvalue = [169, 0]'),
#  Text(0.006572326398159749, 0.6951219512195121, 'x[2] <= 19706.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.006134171304949099, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.007010481491370398, 0.6707317073170732, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.009858489597239622, 0.7439024390243902, 'x[1] <= 2.5\ngini = 0.158\nsamples = 58\nvalue = [53, 5]'),
#  Text(0.008763101864212999, 0.7195121951219512, 'x[2] <= 2120.0\ngini = 0.046\nsamples = 42\nvalue = [41, 1]'),
#  Text(0.008324946771002349, 0.6951219512195121, 'x[3] <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.007886791677791698, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.008763101864212999, 0.6707317073170732, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.009201256957423649, 0.6951219512195121, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(0.010953877330266247, 0.7195121951219512, 'x[2] <= 10227.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.010077567143844947, 0.6951219512195121, 'x[0] <= 42.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.009639412050634299, 0.6707317073170732, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.010515722237055597, 0.6707317073170732, 'x[0] <= 43.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.010077567143844947, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.010953877330266247, 0.6463414634146342, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.011830187516687548, 0.6951219512195121, 'x[2] <= 15154.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.011392032423476897, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.012268342609898198, 0.6707317073170732, 'x[0] <= 30.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.011830187516687548, 0.6463414634146342, 'x[2] <= 17943.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.011392032423476897, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012268342609898198, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.012706497703108848, 0.6463414634146342, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.011172954876871572, 0.7682926829268293, 'x[0] <= 35.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.010734799783660922, 0.7439024390243902, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.011611109970082223, 0.7439024390243902, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.016211738448794047, 0.8170731707317073, 'x[6] <= 10.5\ngini = 0.272\nsamples = 74\nvalue = [62, 12]'),
#  Text(0.014897273169162097, 0.7926829268292683, 'x[12] <= 56.5\ngini = 0.183\nsamples = 49\nvalue = [44, 5]'),
#  Text(0.014459118075951446, 0.7682926829268293, 'x[2] <= 7050.0\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.014020962982740796, 0.7439024390243902, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.014897273169162097, 0.7439024390243902, 'x[2] <= 8028.5\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.014459118075951446, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015335428262372747, 0.7195121951219512, 'x[12] <= 54.5\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.014897273169162097, 0.6951219512195121, 'x[1] <= 3.0\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.014020962982740796, 0.6707317073170732, 'x[0] <= 39.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.013582807889530146, 0.6463414634146342, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.014459118075951446, 0.6463414634146342, 'x[3] <= 5.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.014020962982740796, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.014897273169162097, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015773583355583397, 0.6707317073170732, 'x[2] <= 12834.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.015335428262372747, 0.6463414634146342, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.016211738448794047, 0.6463414634146342, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.015773583355583397, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015335428262372747, 0.7682926829268293, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.017526203728425997, 0.7926829268292683, 'x[2] <= 15784.0\ngini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(0.017088048635215347, 0.7682926829268293, 'x[2] <= 9742.0\ngini = 0.34\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.016649893542004697, 0.7439024390243902, 'x[0] <= 31.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.016211738448794047, 0.7195121951219512, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.017088048635215347, 0.7195121951219512, 'x[3] <= 5.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.016649893542004697, 0.6951219512195121, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.017526203728425997, 0.6951219512195121, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.017526203728425997, 0.7439024390243902, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.017964358821636647, 0.7682926829268293, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.02843215784537233, 0.8414634146341463, 'x[0] <= 19.5\ngini = 0.241\nsamples = 457\nvalue = [393, 64]'),
#  Text(0.02081236692750587, 0.8170731707317073, 'x[2] <= 319.0\ngini = 0.118\nsamples = 159\nvalue = [149, 10]'),
#  Text(0.02037421183429522, 0.7926829268292683, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02125052202071652, 0.7926829268292683, 'x[6] <= 3.5\ngini = 0.107\nsamples = 158\nvalue = [149, 9]'),
#  Text(0.020155134287689894, 0.7682926829268293, 'x[0] <= 12.5\ngini = 0.19\nsamples = 66\nvalue = [59, 7]'),
#  Text(0.019278824101268598, 0.7439024390243902, 'x[0] <= 11.5\ngini = 0.337\nsamples = 28\nvalue = [22, 6]'),
#  Text(0.018840669008057948, 0.7195121951219512, 'x[6] <= 1.0\ngini = 0.302\nsamples = 27\nvalue = [22, 5]'),
#  Text(0.018402513914847297, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.019278824101268598, 0.6951219512195121, 'x[2] <= 14395.0\ngini = 0.26\nsamples = 26\nvalue = [22, 4]'),
#  Text(0.018840669008057948, 0.6707317073170732, 'x[2] <= 13969.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.018402513914847297, 0.6463414634146342, 'x[0] <= 10.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.017526203728425997, 0.6219512195121951, 'x[3] <= 1.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.017088048635215347, 0.5975609756097561, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.017964358821636647, 0.5975609756097561, 'x[0] <= 7.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.017526203728425997, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.018402513914847297, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.019278824101268598, 0.6219512195121951, 'x[12] <= 46.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.018840669008057948, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.019716979194479244, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.019278824101268598, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.019716979194479244, 0.6707317073170732, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.019716979194479244, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.021031444474111195, 0.7439024390243902, 'x[12] <= 43.0\ngini = 0.051\nsamples = 38\nvalue = [37, 1]'),
#  Text(0.020593289380900544, 0.7195121951219512, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.021469599567321845, 0.7195121951219512, 'x[4] <= 5.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.021031444474111195, 0.6951219512195121, 'x[2] <= 4216.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.020593289380900544, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.021469599567321845, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.021907754660532495, 0.6951219512195121, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.022345909753743145, 0.7682926829268293, 'x[2] <= 18980.0\ngini = 0.043\nsamples = 92\nvalue = [90, 2]'),
#  Text(0.021907754660532495, 0.7439024390243902, 'gini = 0.0\nsamples = 82\nvalue = [82, 0]'),
#  Text(0.022784064846953795, 0.7439024390243902, 'x[2] <= 19646.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.022345909753743145, 0.7195121951219512, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.023222219940164445, 0.7195121951219512, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.036051948763238785, 0.8170731707317073, 'x[0] <= 48.5\ngini = 0.297\nsamples = 298\nvalue = [244, 54]'),
#  Text(0.035613793670028135, 0.7926829268292683, 'x[0] <= 41.5\ngini = 0.32\nsamples = 270\nvalue = [216, 54]'),
#  Text(0.03113639631128181, 0.7682926829268293, 'x[0] <= 36.5\ngini = 0.288\nsamples = 218\nvalue = [180, 38]'),
#  Text(0.027658540258922275, 0.7439024390243902, 'x[0] <= 28.5\ngini = 0.33\nsamples = 168\nvalue = [133, 35]'),
#  Text(0.024646223993099056, 0.7195121951219512, 'x[0] <= 24.5\ngini = 0.262\nsamples = 84\nvalue = [71, 13]'),
#  Text(0.02344129748676977, 0.6951219512195121, 'x[3] <= 1.5\ngini = 0.364\nsamples = 46\nvalue = [35, 11]'),
#  Text(0.022345909753743145, 0.6707317073170732, 'x[10] <= 44.0\ngini = 0.295\nsamples = 39\nvalue = [32, 7]'),
#  Text(0.021907754660532495, 0.6463414634146342, 'x[2] <= 11495.5\ngini = 0.266\nsamples = 38\nvalue = [32, 6]'),
#  Text(0.021031444474111195, 0.6219512195121951, 'x[0] <= 21.5\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.020593289380900544, 0.5975609756097561, 'x[2] <= 9050.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.020155134287689894, 0.573170731707317, 'x[2] <= 4567.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.019716979194479244, 0.5487804878048781, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.020593289380900544, 0.5487804878048781, 'x[12] <= 44.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.020155134287689894, 0.524390243902439, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.021031444474111195, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.021031444474111195, 0.573170731707317, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.021469599567321845, 0.5975609756097561, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.022784064846953795, 0.6219512195121951, 'x[2] <= 11758.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.022345909753743145, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.023222219940164445, 0.5975609756097561, 'x[12] <= 43.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.022784064846953795, 0.573170731707317, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.023660375033375095, 0.573170731707317, 'x[6] <= 7.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.023222219940164445, 0.5487804878048781, 'x[2] <= 15725.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.022784064846953795, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.023660375033375095, 0.524390243902439, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.024098530126585745, 0.5487804878048781, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.022784064846953795, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.024536685219796395, 0.6707317073170732, 'x[2] <= 8521.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.024098530126585745, 0.6463414634146342, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.024974840313007046, 0.6463414634146342, 'x[12] <= 43.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.024536685219796395, 0.6219512195121951, 'x[8] <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.024098530126585745, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.024974840313007046, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.025412995406217696, 0.6219512195121951, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.025851150499428346, 0.6951219512195121, 'x[0] <= 26.5\ngini = 0.1\nsamples = 38\nvalue = [36, 2]'),
#  Text(0.025412995406217696, 0.6707317073170732, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.026289305592638996, 0.6707317073170732, 'x[6] <= 5.0\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.025851150499428346, 0.6463414634146342, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.026727460685849646, 0.6463414634146342, 'x[2] <= 11325.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.026289305592638996, 0.6219512195121951, 'x[2] <= 6771.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.025851150499428346, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.026727460685849646, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.027165615779060293, 0.6219512195121951, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.030670856524745493, 0.7195121951219512, 'x[6] <= 12.0\ngini = 0.387\nsamples = 84\nvalue = [62, 22]'),
#  Text(0.028918236151902893, 0.6951219512195121, 'x[8] <= 3.0\ngini = 0.34\nsamples = 69\nvalue = [54, 15]'),
#  Text(0.028480081058692243, 0.6707317073170732, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.029356391245113543, 0.6707317073170732, 'x[2] <= 9945.0\ngini = 0.379\nsamples = 59\nvalue = [44, 15]'),
#  Text(0.028480081058692243, 0.6463414634146342, 'x[0] <= 31.5\ngini = 0.301\nsamples = 38\nvalue = [31, 7]'),
#  Text(0.028041925965481593, 0.6219512195121951, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.028918236151902893, 0.6219512195121951, 'x[2] <= 8457.0\ngini = 0.375\nsamples = 28\nvalue = [21, 7]'),
#  Text(0.028480081058692243, 0.5975609756097561, 'x[6] <= 9.0\ngini = 0.455\nsamples = 20\nvalue = [13, 7]'),
#  Text(0.028041925965481593, 0.573170731707317, 'x[6] <= 5.0\ngini = 0.432\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.027603770872270943, 0.5487804878048781, 'x[1] <= 1.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.027165615779060293, 0.524390243902439, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.028041925965481593, 0.524390243902439, 'x[3] <= 0.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.027165615779060293, 0.5, 'x[12] <= 36.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.026727460685849646, 0.47560975609756095, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.027603770872270943, 0.47560975609756095, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.028918236151902893, 0.5, 'x[1] <= 3.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.028480081058692243, 0.47560975609756095, 'x[2] <= 898.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.028041925965481593, 0.45121951219512196, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.028918236151902893, 0.45121951219512196, 'x[2] <= 5887.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.028480081058692243, 0.4268292682926829, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.029356391245113543, 0.4268292682926829, 'x[2] <= 6560.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.028918236151902893, 0.4024390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.029794546338324193, 0.4024390243902439, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.029356391245113543, 0.47560975609756095, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.028480081058692243, 0.5487804878048781, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.028918236151902893, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.029356391245113543, 0.5975609756097561, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.030232701431534843, 0.6463414634146342, 'x[2] <= 11918.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.029794546338324193, 0.6219512195121951, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.030670856524745493, 0.6219512195121951, 'x[4] <= 6.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.030232701431534843, 0.5975609756097561, 'x[6] <= 2.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.029794546338324193, 0.573170731707317, 'x[4] <= 5.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.029356391245113543, 0.5487804878048781, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.030232701431534843, 0.5487804878048781, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.030670856524745493, 0.573170731707317, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.031109011617956144, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.032423476897588094, 0.6951219512195121, 'x[2] <= 3689.5\ngini = 0.498\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.031985321804377444, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.032861631990798744, 0.6707317073170732, 'x[2] <= 10555.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.031985321804377444, 0.6463414634146342, 'x[12] <= 70.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.031547166711166794, 0.6219512195121951, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.032423476897588094, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.033737942177220044, 0.6463414634146342, 'x[0] <= 32.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.033299787084009394, 0.6219512195121951, 'x[2] <= 16422.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.032861631990798744, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.033737942177220044, 0.5975609756097561, 'x[8] <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.033299787084009394, 0.573170731707317, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.034176097270430694, 0.573170731707317, 'x[12] <= 34.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.033737942177220044, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.034614252363641344, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.034176097270430694, 0.6219512195121951, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.034614252363641344, 0.7439024390243902, 'x[13] <= 12.5\ngini = 0.113\nsamples = 50\nvalue = [47, 3]'),
#  Text(0.034176097270430694, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.035052407456851994, 0.7195121951219512, 'x[2] <= 2381.0\ngini = 0.078\nsamples = 49\nvalue = [47, 2]'),
#  Text(0.034176097270430694, 0.6951219512195121, 'x[3] <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.033737942177220044, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.034614252363641344, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.035928717643273295, 0.6951219512195121, 'x[0] <= 40.5\ngini = 0.042\nsamples = 47\nvalue = [46, 1]'),
#  Text(0.035490562550062645, 0.6707317073170732, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]'),
#  Text(0.036366872736483945, 0.6707317073170732, 'x[3] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.035928717643273295, 0.6463414634146342, 'x[2] <= 6880.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.035490562550062645, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.036366872736483945, 0.6219512195121951, 'x[2] <= 11179.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.035928717643273295, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.036805027829694595, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.036805027829694595, 0.6463414634146342, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.04009119102877447, 0.7682926829268293, 'x[6] <= 8.0\ngini = 0.426\nsamples = 52\nvalue = [36, 16]'),
#  Text(0.038119493109326545, 0.7439024390243902, 'x[2] <= 2710.0\ngini = 0.327\nsamples = 34\nvalue = [27, 7]'),
#  Text(0.037243182922905245, 0.7195121951219512, 'x[1] <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.036805027829694595, 0.6951219512195121, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.037681338016115895, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03899580329574784, 0.7195121951219512, 'x[2] <= 19759.5\ngini = 0.271\nsamples = 31\nvalue = [26, 5]'),
#  Text(0.038557648202537195, 0.6951219512195121, 'x[6] <= 2.5\ngini = 0.231\nsamples = 30\nvalue = [26, 4]'),
#  Text(0.038119493109326545, 0.6707317073170732, 'x[2] <= 4408.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.037681338016115895, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.038557648202537195, 0.6463414634146342, 'x[8] <= 3.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.038119493109326545, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03899580329574784, 0.6219512195121951, 'x[2] <= 8091.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.038557648202537195, 0.5975609756097561, 'x[2] <= 7378.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.038119493109326545, 0.573170731707317, 'x[3] <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.037681338016115895, 0.5487804878048781, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.038557648202537195, 0.5487804878048781, 'x[1] <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.038119493109326545, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03899580329574784, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03899580329574784, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03943395838895849, 0.5975609756097561, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.03899580329574784, 0.6707317073170732, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.03943395838895849, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04206288894822239, 0.7439024390243902, 'x[1] <= 2.5\ngini = 0.5\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.04162473385501174, 0.7195121951219512, 'x[12] <= 41.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]'),
#  Text(0.04118657876180109, 0.6951219512195121, 'x[6] <= 10.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.04074842366859044, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04162473385501174, 0.6707317073170732, 'x[4] <= 6.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.04118657876180109, 0.6463414634146342, 'x[0] <= 43.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.04074842366859044, 0.6219512195121951, 'x[11] <= 8.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.04031026857537979, 0.5975609756097561, 'x[2] <= 5161.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.03987211348216914, 0.573170731707317, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.04074842366859044, 0.573170731707317, 'x[2] <= 15644.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.04031026857537979, 0.5487804878048781, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04118657876180109, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04118657876180109, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04162473385501174, 0.6219512195121951, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.04206288894822239, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04206288894822239, 0.6951219512195121, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04250104404143304, 0.7195121951219512, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.036490103856449435, 0.7926829268292683, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.037804569136081385, 0.8658536585365854, 'x[11] <= 51.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.037366414042870735, 0.8414634146341463, 'x[4] <= 3.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.036928258949660085, 0.8170731707317073, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.037804569136081385, 0.8170731707317073, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.038242724229292036, 0.8414634146341463, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.22538504280309132, 0.8902439024390244, 'x[0] <= 18.5\ngini = 0.448\nsamples = 4877\nvalue = [3228, 1649]'),
#  Text(0.09416202731452004, 0.8658536585365854, 'x[0] <= 10.5\ngini = 0.336\nsamples = 1604\nvalue = [1261, 343]'),
#  Text(0.05873674409688705, 0.8414634146341463, 'x[6] <= 12.5\ngini = 0.183\nsamples = 411\nvalue = [369, 42]'),
#  Text(0.05290038133185456, 0.8170731707317073, 'x[13] <= 0.5\ngini = 0.157\nsamples = 372\nvalue = [340, 32]'),
#  Text(0.05246222623864391, 0.7926829268292683, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05333853642506521, 0.7926829268292683, 'x[12] <= 53.5\ngini = 0.153\nsamples = 371\nvalue = [340, 31]'),
#  Text(0.04884060054632463, 0.7682926829268293, 'x[0] <= 8.5\ngini = 0.125\nsamples = 329\nvalue = [307, 22]'),
#  Text(0.04469181950748629, 0.7439024390243902, 'x[10] <= 45.5\ngini = 0.052\nsamples = 189\nvalue = [184, 5]'),
#  Text(0.04381550932106499, 0.7195121951219512, 'x[3] <= 13.0\ngini = 0.042\nsamples = 186\nvalue = [182, 4]'),
#  Text(0.04337735422785434, 0.6951219512195121, 'gini = 0.0\nsamples = 124\nvalue = [124, 0]'),
#  Text(0.04425366441427564, 0.6951219512195121, 'x[12] <= 42.5\ngini = 0.121\nsamples = 62\nvalue = [58, 4]'),
#  Text(0.04337735422785434, 0.6707317073170732, 'x[2] <= 17996.5\ngini = 0.071\nsamples = 54\nvalue = [52, 2]'),
#  Text(0.04293919913464369, 0.6463414634146342, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(0.04381550932106499, 0.6463414634146342, 'x[2] <= 18078.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.04337735422785434, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04425366441427564, 0.6219512195121951, 'x[6] <= 1.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.04381550932106499, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04469181950748629, 0.5975609756097561, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.04512997460069694, 0.6707317073170732, 'x[6] <= 9.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.04469181950748629, 0.6463414634146342, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.04556812969390759, 0.6463414634146342, 'x[2] <= 14813.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.04512997460069694, 0.6219512195121951, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04600628478711824, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04556812969390759, 0.7195121951219512, 'x[1] <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04512997460069694, 0.6951219512195121, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.04600628478711824, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.052989381585162976, 0.7439024390243902, 'x[2] <= 369.5\ngini = 0.213\nsamples = 140\nvalue = [123, 17]'),
#  Text(0.052551226491952326, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.053427536678373626, 0.7195121951219512, 'x[1] <= 4.5\ngini = 0.204\nsamples = 139\nvalue = [123, 16]'),
#  Text(0.05186660915881068, 0.6951219512195121, 'x[4] <= 10.5\ngini = 0.186\nsamples = 135\nvalue = [121, 14]'),
#  Text(0.050059219399316755, 0.6707317073170732, 'x[3] <= 13.0\ngini = 0.168\nsamples = 130\nvalue = [118, 12]'),
#  Text(0.04775890515996084, 0.6463414634146342, 'x[2] <= 12444.5\ngini = 0.112\nsamples = 84\nvalue = [79, 5]'),
#  Text(0.04688259497353954, 0.6219512195121951, 'x[2] <= 2802.0\ngini = 0.036\nsamples = 54\nvalue = [53, 1]'),
#  Text(0.04644443988032889, 0.5975609756097561, 'x[2] <= 2338.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.04600628478711824, 0.573170731707317, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.04688259497353954, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04732075006675019, 0.5975609756097561, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.04863521534638214, 0.6219512195121951, 'x[2] <= 12557.0\ngini = 0.231\nsamples = 30\nvalue = [26, 4]'),
#  Text(0.04819706025317149, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04907337043959279, 0.5975609756097561, 'x[6] <= 9.5\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.04775890515996084, 0.573170731707317, 'x[12] <= 41.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.04732075006675019, 0.5487804878048781, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.04819706025317149, 0.5487804878048781, 'x[0] <= 9.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.04775890515996084, 0.524390243902439, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.04863521534638214, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05038783571922474, 0.573170731707317, 'x[0] <= 9.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.04994968062601409, 0.5487804878048781, 'x[12] <= 37.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.04951152553280344, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05038783571922474, 0.524390243902439, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05082599081243539, 0.5487804878048781, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.05235953363867266, 0.6463414634146342, 'x[8] <= 1.5\ngini = 0.258\nsamples = 46\nvalue = [39, 7]'),
#  Text(0.05192137854546201, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05279768873188331, 0.6219512195121951, 'x[2] <= 798.0\ngini = 0.231\nsamples = 45\nvalue = [39, 6]'),
#  Text(0.05170230099885669, 0.5975609756097561, 'x[2] <= 601.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05126414590564604, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05214045609206734, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05389307646490994, 0.5975609756097561, 'x[2] <= 13417.0\ngini = 0.206\nsamples = 43\nvalue = [38, 5]'),
#  Text(0.05301676627848864, 0.573170731707317, 'x[6] <= 2.5\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.05257861118527799, 0.5487804878048781, 'x[0] <= 9.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.05214045609206734, 0.524390243902439, 'x[2] <= 8392.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.05170230099885669, 0.5, 'x[6] <= 1.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.05126414590564604, 0.47560975609756095, 'x[11] <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05082599081243539, 0.45121951219512196, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05170230099885669, 0.45121951219512196, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05214045609206734, 0.47560975609756095, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.05257861118527799, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05301676627848864, 0.524390243902439, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.05345492137169929, 0.5487804878048781, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.054769386651331235, 0.573170731707317, 'x[2] <= 13660.0\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.054331231558120585, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.055207541744541885, 0.5487804878048781, 'x[0] <= 9.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.054769386651331235, 0.524390243902439, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.055645696837752535, 0.524390243902439, 'x[6] <= 8.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.055207541744541885, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.056083851930963186, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05367399891830461, 0.6707317073170732, 'x[0] <= 9.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.05323584382509396, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.054112154011515264, 0.6463414634146342, 'x[2] <= 15837.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.05367399891830461, 0.6219512195121951, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.054550309104725914, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.054988464197936564, 0.6951219512195121, 'x[2] <= 1996.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.054550309104725914, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.055426619291147214, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.057836472303805786, 0.7682926829268293, 'x[1] <= 1.5\ngini = 0.337\nsamples = 42\nvalue = [33, 9]'),
#  Text(0.056960162117384486, 0.7439024390243902, 'x[2] <= 1899.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.056522007024173836, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.057398317210595136, 0.7195121951219512, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.058712782490227086, 0.7439024390243902, 'x[2] <= 19630.0\ngini = 0.266\nsamples = 38\nvalue = [32, 6]'),
#  Text(0.058274627397016436, 0.7195121951219512, 'x[8] <= 3.0\ngini = 0.234\nsamples = 37\nvalue = [32, 5]'),
#  Text(0.056741084570779164, 0.6951219512195121, 'x[2] <= 13583.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.056302929477568514, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.057179239663989814, 0.6707317073170732, 'x[6] <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.056741084570779164, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.057617394757200464, 0.6463414634146342, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.059808170223253715, 0.6951219512195121, 'x[0] <= 8.5\ngini = 0.17\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.059370015130043065, 0.6707317073170732, 'x[2] <= 9222.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.058493704943621765, 0.6463414634146342, 'x[6] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.058055549850411114, 0.6219512195121951, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.058931860036832415, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.060246325316464365, 0.6463414634146342, 'x[0] <= 7.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.059808170223253715, 0.6219512195121951, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.060684480409675015, 0.6219512195121951, 'x[3] <= 13.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.060246325316464365, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.061122635502885665, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.060246325316464365, 0.6707317073170732, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.059150937583437736, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06457310686191953, 0.8170731707317073, 'x[2] <= 18532.5\ngini = 0.381\nsamples = 39\nvalue = [29, 10]'),
#  Text(0.06298479464903092, 0.7926829268292683, 'x[2] <= 2934.5\ngini = 0.346\nsamples = 36\nvalue = [28, 8]'),
#  Text(0.061122635502885665, 0.7682926829268293, 'x[12] <= 53.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.060684480409675015, 0.7439024390243902, 'x[2] <= 2147.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.060246325316464365, 0.7195121951219512, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.061122635502885665, 0.7195121951219512, 'x[3] <= 13.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.060684480409675015, 0.6951219512195121, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.061560790596096315, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.061560790596096315, 0.7439024390243902, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06484695379517619, 0.7682926829268293, 'x[12] <= 46.5\ngini = 0.252\nsamples = 27\nvalue = [23, 4]'),
#  Text(0.06440879870196553, 0.7439024390243902, 'x[3] <= 13.0\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.06331341096893892, 0.7195121951219512, 'x[2] <= 6455.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.06243710078251761, 0.6951219512195121, 'x[8] <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06199894568930696, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06287525587572826, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06418972115536022, 0.6951219512195121, 'x[12] <= 41.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.06375156606214956, 0.6707317073170732, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.06462787624857086, 0.6707317073170732, 'x[2] <= 11222.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06418972115536022, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06506603134178152, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06550418643499216, 0.7195121951219512, 'x[2] <= 9545.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.06506603134178152, 0.6951219512195121, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06594234152820282, 0.6951219512195121, 'x[2] <= 14707.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06550418643499216, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06638049662141346, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06528510888838683, 0.7439024390243902, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.06616141907480813, 0.7926829268292683, 'x[2] <= 19465.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06572326398159749, 0.7682926829268293, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06659957416801879, 0.7682926829268293, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12958731053215305, 0.8414634146341463, 'x[11] <= 40.5\ngini = 0.377\nsamples = 1193\nvalue = [892, 301]'),
#  Text(0.1101625238760295, 0.8170731707317073, 'x[12] <= 48.0\ngini = 0.363\nsamples = 1154\nvalue = [879, 275]'),
#  Text(0.08369682234864823, 0.7926829268292683, 'x[2] <= 4657.5\ngini = 0.331\nsamples = 835\nvalue = [660, 175]'),
#  Text(0.07185743528654659, 0.7682926829268293, 'x[6] <= 8.0\ngini = 0.212\nsamples = 191\nvalue = [168, 23]'),
#  Text(0.06835219454086139, 0.7439024390243902, 'x[2] <= 55.0\ngini = 0.121\nsamples = 139\nvalue = [130, 9]'),
#  Text(0.06791403944765073, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06879034963407203, 0.7195121951219512, 'x[13] <= 17.5\ngini = 0.109\nsamples = 138\nvalue = [130, 8]'),
#  Text(0.06769496190104542, 0.6951219512195121, 'x[2] <= 2430.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06725680680783476, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06813311699425606, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06988573736709866, 0.6951219512195121, 'x[2] <= 782.0\ngini = 0.098\nsamples = 136\nvalue = [129, 7]'),
#  Text(0.06900942718067736, 0.6707317073170732, 'x[2] <= 759.5\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.06857127208746672, 0.6463414634146342, 'x[1] <= 2.5\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.06769496190104542, 0.6219512195121951, 'x[4] <= 9.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.06725680680783476, 0.5975609756097561, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.06813311699425606, 0.5975609756097561, 'x[6] <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.06769496190104542, 0.573170731707317, 'x[3] <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06725680680783476, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06813311699425606, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06857127208746672, 0.573170731707317, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06944758227388802, 0.6219512195121951, 'x[12] <= 41.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06900942718067736, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06988573736709866, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06944758227388802, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07076204755351996, 0.6707317073170732, 'x[2] <= 2000.5\ngini = 0.069\nsamples = 111\nvalue = [107, 4]'),
#  Text(0.0703238924603093, 0.6463414634146342, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.0712002026467306, 0.6463414634146342, 'x[2] <= 2020.5\ngini = 0.128\nsamples = 58\nvalue = [54, 4]'),
#  Text(0.07076204755351996, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07163835773994126, 0.6219512195121951, 'x[0] <= 16.5\ngini = 0.1\nsamples = 57\nvalue = [54, 3]'),
#  Text(0.0712002026467306, 0.5975609756097561, 'x[0] <= 12.5\ngini = 0.145\nsamples = 38\nvalue = [35, 3]'),
#  Text(0.07076204755351996, 0.573170731707317, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.07163835773994126, 0.573170731707317, 'x[2] <= 2445.0\ngini = 0.219\nsamples = 24\nvalue = [21, 3]'),
#  Text(0.07076204755351996, 0.5487804878048781, 'x[0] <= 14.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0703238924603093, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0712002026467306, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07251466792636256, 0.5487804878048781, 'x[2] <= 3214.0\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.0720765128331519, 0.524390243902439, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.0729528230195732, 0.524390243902439, 'x[2] <= 3257.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.07251466792636256, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07339097811278386, 0.5, 'x[1] <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.0729528230195732, 0.47560975609756095, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0738291332059945, 0.47560975609756095, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0720765128331519, 0.5975609756097561, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.07536267603223179, 0.7439024390243902, 'x[2] <= 4077.0\ngini = 0.393\nsamples = 52\nvalue = [38, 14]'),
#  Text(0.07492452093902113, 0.7195121951219512, 'x[2] <= 1981.0\ngini = 0.455\nsamples = 40\nvalue = [26, 14]'),
#  Text(0.07339097811278386, 0.6951219512195121, 'x[2] <= 190.5\ngini = 0.34\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.07251466792636256, 0.6707317073170732, 'x[2] <= 104.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.0720765128331519, 0.6463414634146342, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0729528230195732, 0.6463414634146342, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07426728829920516, 0.6707317073170732, 'x[0] <= 16.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.0738291332059945, 0.6463414634146342, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.0747054433924158, 0.6463414634146342, 'x[6] <= 12.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.07426728829920516, 0.6219512195121951, 'x[2] <= 1774.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0738291332059945, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0747054433924158, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07514359848562646, 0.6219512195121951, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.0764580637652584, 0.6951219512195121, 'x[4] <= 8.5\ngini = 0.498\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.07601990867204776, 0.6707317073170732, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.07689621885846906, 0.6707317073170732, 'x[3] <= 11.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.0764580637652584, 0.6463414634146342, 'x[2] <= 2780.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.07601990867204776, 0.6219512195121951, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07689621885846906, 0.6219512195121951, 'x[0] <= 15.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.0764580637652584, 0.5975609756097561, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
# ...
#  Text(0.1175624884470825, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11800064354029316, 0.5487804878048781, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.11975326391313575, 0.5975609756097561, 'x[0] <= 16.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.1193151088199251, 0.573170731707317, 'x[12] <= 41.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.11887695372671445, 0.5487804878048781, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11975326391313575, 0.5487804878048781, 'x[1] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1193151088199251, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1201914190063464, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1201914190063464, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1193151088199251, 0.6463414634146342, 'x[2] <= 16904.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.11887695372671445, 0.6219512195121951, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11975326391313575, 0.6219512195121951, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.13662822540341077, 0.7926829268292683, 'x[0] <= 13.5\ngini = 0.43\nsamples = 319\nvalue = [219, 100]'),
#  Text(0.1259969739913875, 0.7682926829268293, 'x[2] <= 641.0\ngini = 0.317\nsamples = 96\nvalue = [77, 19]'),
#  Text(0.12555881889817685, 0.7439024390243902, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12643512908459817, 0.7439024390243902, 'x[13] <= 5.5\ngini = 0.307\nsamples = 95\nvalue = [77, 18]'),
#  Text(0.1259969739913875, 0.7195121951219512, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12687328417780883, 0.7195121951219512, 'x[11] <= 8.5\ngini = 0.296\nsamples = 94\nvalue = [77, 17]'),
#  Text(0.12643512908459817, 0.6951219512195121, 'x[2] <= 17283.0\ngini = 0.285\nsamples = 93\nvalue = [77, 16]'),
#  Text(0.12435389239184758, 0.6707317073170732, 'x[6] <= 5.5\ngini = 0.252\nsamples = 81\nvalue = [69, 12]'),
#  Text(0.12238219447239965, 0.6463414634146342, 'x[2] <= 1922.0\ngini = 0.159\nsamples = 46\nvalue = [42, 4]'),
#  Text(0.1210677291927677, 0.6219512195121951, 'x[12] <= 56.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.12062957409955705, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12150588428597835, 0.5975609756097561, 'x[3] <= 13.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1210677291927677, 0.573170731707317, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.121944039379189, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1236966597520316, 0.6219512195121951, 'x[2] <= 8011.5\ngini = 0.093\nsamples = 41\nvalue = [39, 2]'),
#  Text(0.12325850465882095, 0.5975609756097561, 'x[2] <= 7442.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.1228203495656103, 0.573170731707317, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.1236966597520316, 0.573170731707317, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12413481484524225, 0.5975609756097561, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.1263255903112955, 0.6463414634146342, 'x[6] <= 12.5\ngini = 0.353\nsamples = 35\nvalue = [27, 8]'),
#  Text(0.12588743521808485, 0.6219512195121951, 'x[6] <= 11.5\ngini = 0.454\nsamples = 23\nvalue = [15, 8]'),
#  Text(0.1254492801248742, 0.5975609756097561, 'x[4] <= 8.5\ngini = 0.408\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.1245729699384529, 0.573170731707317, 'x[12] <= 56.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.12413481484524225, 0.5487804878048781, 'x[2] <= 14676.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.1236966597520316, 0.524390243902439, 'x[1] <= 3.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.12325850465882095, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.12413481484524225, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1245729699384529, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12501112503166356, 0.5487804878048781, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1263255903112955, 0.573170731707317, 'x[2] <= 9125.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.12588743521808485, 0.5487804878048781, 'x[2] <= 8432.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1254492801248742, 0.524390243902439, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1263255903112955, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12676374540450616, 0.5487804878048781, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1263255903112955, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12676374540450616, 0.6219512195121951, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.12851636577734876, 0.6707317073170732, 'x[2] <= 18447.0\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.1280782106841381, 0.6463414634146342, 'x[8] <= 2.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.12764005559092745, 0.6219512195121951, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12851636577734876, 0.6219512195121951, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1289545208705594, 0.6463414634146342, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.12731143927101946, 0.6951219512195121, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14725947681543403, 0.7682926829268293, 'x[1] <= 3.5\ngini = 0.463\nsamples = 223\nvalue = [142, 81]'),
#  Text(0.1411372863138149, 0.7439024390243902, 'x[12] <= 51.5\ngini = 0.485\nsamples = 177\nvalue = [104, 73]'),
#  Text(0.13399330444248186, 0.7195121951219512, 'x[2] <= 19166.0\ngini = 0.427\nsamples = 94\nvalue = [65, 29]'),
#  Text(0.13311699425606058, 0.6951219512195121, 'x[13] <= 16.0\ngini = 0.397\nsamples = 88\nvalue = [64, 24]'),
#  Text(0.13267883916284992, 0.6707317073170732, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13355514934927123, 0.6707317073170732, 'x[10] <= 66.0\ngini = 0.381\nsamples = 86\nvalue = [64, 22]'),
#  Text(0.13311699425606058, 0.6463414634146342, 'x[0] <= 17.5\ngini = 0.363\nsamples = 84\nvalue = [64, 20]'),
#  Text(0.1298308310569807, 0.6219512195121951, 'x[2] <= 5106.0\ngini = 0.292\nsamples = 62\nvalue = [51, 11]'),
#  Text(0.12939267596377005, 0.5975609756097561, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.13026898615019136, 0.5975609756097561, 'x[2] <= 8438.0\ngini = 0.359\nsamples = 47\nvalue = [36, 11]'),
#  Text(0.12851636577734876, 0.573170731707317, 'x[0] <= 15.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.12764005559092745, 0.5487804878048781, 'x[1] <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1272019004977168, 0.524390243902439, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1280782106841381, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12939267596377005, 0.5487804878048781, 'x[6] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1289545208705594, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1298308310569807, 0.524390243902439, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13202160652303396, 0.573170731707317, 'x[3] <= 13.0\ngini = 0.266\nsamples = 38\nvalue = [32, 6]'),
#  Text(0.13114529633661265, 0.5487804878048781, 'x[6] <= 2.5\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.130707141243402, 0.524390243902439, 'x[2] <= 14483.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.13026898615019136, 0.5, 'x[0] <= 14.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1298308310569807, 0.47560975609756095, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.130707141243402, 0.47560975609756095, 'x[2] <= 13366.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.13026898615019136, 0.45121951219512196, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13114529633661265, 0.45121951219512196, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13114529633661265, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1315834514298233, 0.524390243902439, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.13289791670945525, 0.5487804878048781, 'x[6] <= 2.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.1324597616162446, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1333360718026659, 0.524390243902439, 'x[2] <= 16629.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.13289791670945525, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.13377422689587656, 0.5, 'x[2] <= 18166.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.1333360718026659, 0.47560975609756095, 'x[2] <= 17500.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.13289791670945525, 0.45121951219512196, 'x[2] <= 16936.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1324597616162446, 0.4268292682926829, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1333360718026659, 0.4268292682926829, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13377422689587656, 0.45121951219512196, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1342123819890872, 0.47560975609756095, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13640315745514045, 0.6219512195121951, 'x[1] <= 2.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.1359650023619298, 0.5975609756097561, 'x[6] <= 3.5\ngini = 0.432\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.1350886921755085, 0.573170731707317, 'x[2] <= 11960.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.13465053708229785, 0.5487804878048781, 'x[4] <= 8.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1342123819890872, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1350886921755085, 0.524390243902439, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13552684726871914, 0.5487804878048781, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1368413125483511, 0.573170731707317, 'x[2] <= 685.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.13640315745514045, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13727946764156174, 0.5487804878048781, 'x[2] <= 11612.0\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.1368413125483511, 0.524390243902439, 'x[2] <= 9603.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.13640315745514045, 0.5, 'x[6] <= 12.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1359650023619298, 0.47560975609756095, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1368413125483511, 0.47560975609756095, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13727946764156174, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1377176227347724, 0.524390243902439, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1368413125483511, 0.5975609756097561, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.13399330444248186, 0.6463414634146342, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13486961462890318, 0.6951219512195121, 'x[1] <= 1.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.13443145953569252, 0.6707317073170732, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13530776972211384, 0.6707317073170732, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.14828126818514792, 0.7195121951219512, 'x[2] <= 17568.0\ngini = 0.498\nsamples = 83\nvalue = [39, 44]'),
#  Text(0.1463574934790199, 0.6951219512195121, 'x[12] <= 72.5\ngini = 0.491\nsamples = 74\nvalue = [32, 42]'),
#  Text(0.14382440934639584, 0.6707317073170732, 'x[12] <= 60.5\ngini = 0.498\nsamples = 66\nvalue = [31, 35]'),
#  Text(0.14007270636077965, 0.6463414634146342, 'x[0] <= 14.5\ngini = 0.477\nsamples = 51\nvalue = [20, 31]'),
#  Text(0.1385939329211937, 0.6219512195121951, 'x[4] <= 9.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.13815577782798305, 0.5975609756097561, 'x[2] <= 9535.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.1377176227347724, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1385939329211937, 0.573170731707317, 'x[2] <= 12876.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.13815577782798305, 0.5487804878048781, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13903208801440434, 0.5487804878048781, 'x[2] <= 13338.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.1385939329211937, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.139470243107615, 0.524390243902439, 'x[4] <= 8.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13903208801440434, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13990839820082565, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13903208801440434, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1415514798003656, 0.6219512195121951, 'x[0] <= 15.5\ngini = 0.444\nsamples = 42\nvalue = [14, 28]'),
#  Text(0.13990839820082565, 0.5975609756097561, 'x[11] <= 16.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.139470243107615, 0.573170731707317, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.1403465532940363, 0.573170731707317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14319456139990552, 0.5975609756097561, 'x[12] <= 56.5\ngini = 0.487\nsamples = 31\nvalue = [13, 18]'),
#  Text(0.1412228634804576, 0.573170731707317, 'x[13] <= 31.5\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.14078470838724694, 0.5487804878048781, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14166101857366825, 0.5487804878048781, 'x[4] <= 10.0\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.1412228634804576, 0.524390243902439, 'x[2] <= 10002.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.14078470838724694, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.14166101857366825, 0.5, 'x[2] <= 11994.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.1412228634804576, 0.47560975609756095, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1420991736668789, 0.47560975609756095, 'x[0] <= 17.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.14166101857366825, 0.45121951219512196, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.14253732876008954, 0.45121951219512196, 'x[2] <= 16165.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1420991736668789, 0.4268292682926829, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1429754838533002, 0.4268292682926829, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1420991736668789, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14516625931935345, 0.573170731707317, 'x[2] <= 15126.5\ngini = 0.48\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.14428994913293214, 0.5487804878048781, 'x[12] <= 59.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.1438517940397215, 0.524390243902439, 'x[2] <= 11351.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.14341363894651085, 0.5, 'x[2] <= 7069.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1429754838533002, 0.47560975609756095, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1438517940397215, 0.47560975609756095, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14428994913293214, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1447281042261428, 0.524390243902439, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14604256950577474, 0.5487804878048781, 'x[2] <= 16438.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1456044144125641, 0.524390243902439, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1464807245989854, 0.524390243902439, 'x[1] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14604256950577474, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14691887969219605, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.147576112332012, 0.6463414634146342, 'x[0] <= 14.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.1464807245989854, 0.6219512195121951, 'x[2] <= 10448.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.14604256950577474, 0.5975609756097561, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14691887969219605, 0.5975609756097561, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  ...]

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)
rf=RandomForestClassifier(n_estimators=300)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[4179  579]
#  [ 304  971]]
# accuracy_score : 0.8536383225592574
